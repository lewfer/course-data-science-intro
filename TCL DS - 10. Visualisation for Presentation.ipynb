# %% [markdown]
# # Visualisation for Presentation
#
# In this set of worksheets, we will use a number of libraries to explore presentation visualisations.  Click on the links to open up the individual worksheets.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# [1. Matplotlib](vis-pres/TCL%20DS%20-%2010a.%20Matplotlib.ipynb)
#
# [2. Other visualisation libraries](vis-pres/TCL%20DS%20-%2010b.%20Other%20Visualisation%20Libraries.ipynb)
#
# [3. Plotly](vis-pres/TCL%20DS%20-%2010c.%20Visualisation%20with%20Plotly.ipynb)
#
# [4. Bokeh](vis-pres/TCL%20DS%20-%2010d.%20Visualisation%20with%20Bokeh.ipynb)
#
# [5. D3](vis-pres/TCL%20DS%20-%2010e.%20Visualisation%20with%20D3.ipynb)
#
# [6. Maps with Folium](vis-pres/TCL%20DS%20-%2010f.%20Mapping%20with%20Folium.ipynb)
