# %% [markdown]
# # Visualisation for Analytics
# In this set of worksheets, we will use the Seaborn library to carry out some analysis of our data.  Click on the links to open up the individual worksheets.
# ![image.png](attachment:image.png)

# %% [markdown]
# [Seaborn 1. Basics](./vis-anal/TCL%20Seaborn%20-%201.%20Basics.ipynb)
#
# [Seaborn 2. Categorical Data](./vis-anal/TCL%20Seaborn%20-%202.%20Categorical%20Data.ipynb)
#
# [Seaborn 3. Univariate Distributions](./vis-anal/TCL%20Seaborn%20-%203.%20Univariate%20Distributions.ipynb)
#
# [Seaborn 4. Bivariate Distributions](./vis-anal/TCL%20Seaborn%20-%204.%20Bivariate%20Distributions.ipynb)
#
# [Seaborn 5. Regression](./vis-anal/TCL%20Seaborn%20-%205.%20Regression.ipynb)
#
# [Seaborn 6. Lattice Plots](./vis-anal/TCL%20Seaborn%20-%206.%20Lattice%20Plots.ipynb)
#
# [Seaborn 7. Styling](./vis-anal/TCL%20Seaborn%20-%207.%20Styling.ipynb)
#
# [Seaborn 8. Other Options](./vis-anal/TCL%20Seaborn%20-%208.%20Further%20Options.ipynb)
