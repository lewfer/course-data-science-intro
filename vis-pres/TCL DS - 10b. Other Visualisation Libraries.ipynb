# %% [markdown]
# # Other visualisation libraries
#
# So far we have used Matplotlib to visualise our data.  Matplotlib is very convenient but doesn't give the most options when it comes to visualisation.  Let's look at some other visualisation libraries and techniques.
#
# To do this we will take the university rankings data that we have previously used and draw a simple scatter plot with each library.  You will be able to compare the approaches and difficulty of using the different libraries.
#
# We will also take a look at some of the possibilties of these other libraries and discuss how you can explore these yourself.
#
# The diagram below shows the huge number of options available to you once you start looking into data visualisation libraries!
#
# ![vislibs.png](attachment:vislibs.png)
